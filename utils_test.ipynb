# %%
from utils import files

files.read_csv("./utils/1-10.csv")
# Out:
# [{'prompt': '((masterpiece)),\xa0(((best\xa0quality))),\xa0((ultra-detailed)),\xa0((illustration)),\xa0((disheveled\xa0hair)),\xa0((frills)),\xa0(1\xa0girl),\xa0(solo),\xa0dynamic\xa0angle,\xa0big\xa0top\xa0sleeves,\xa0floating,\xa0beautiful\xa0detailed\xa0sky,\xa0on\xa0beautiful\xa0detailed\xa0water,\xa0beautiful\xa0detailed\xa0eyes,\xa0overexposure,\xa0(fist),\xa0expressionless,\xa0side\xa0blunt\xa0bangs,\xa0hairs\xa0between\xa0eyes,\xa0ribbons,\xa0bowties,\xa0buttons,\xa0bare\xa0shoulders,\xa0(((small\xa0breast))),\xa0detailed\xa0wet\xa0clothes,\xa0blank\xa0stare,\xa0pleated\xa0skirt,\xa0flowers\x05',
# ...
